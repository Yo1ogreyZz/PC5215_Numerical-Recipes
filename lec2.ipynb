# %% [markdown]
# ![image.png](attachment:f7fa1e41-dba6-4a45-a4e3-c46132df1a3b.png)
# ![image.png](attachment:ecd0e96c-5e89-42d2-bf9d-290cf3f88b6c.png)
# ![image.png](attachment:8d9cf101-1988-442a-90bb-d9bea7a05751.png)
